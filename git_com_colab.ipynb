# %% [markdown]
# <a href="https://colab.research.google.com/github/torres970823-cyber/base_dados_alunos/blob/main/git_com_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!git colne colar a url
# !git clone https://github.com/torres970823-cyber/base_dados_alunos
# Out:
# fatal: destination path 'base_dados_alunos' already exists and is not an empty directory.

# %%
#vamos contar quantos alunos temos
#1 saber onde esta o arquivo
#2 perdirr que o python leia o arquivo
#3 contar as informações e mostrar

baseDados = "/content/base_dados_alunos/github - Página1.csv"

# usar uma função de abertura de aquivos
#with open (arquivo,metodo) (as) apelido
#metodos - leitura - "r" read
#metodos - colocar informaçoes - "a" append
#metodos - deletar tudo e colocar de novo  - "w" write
with open(baseDados, "r") as arquivo:
  qtd_linhas = arquivo.readlines()

print(len (qtd_linhas))
# Out:
# 53
